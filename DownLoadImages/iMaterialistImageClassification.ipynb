# %%
from DownLoadImage import startDownloadImage

# %%
startDownloadImage()
# Out:
# start Entering Main Thread...
#
# Starting Thread-1
#
# Starting Thread-2
#
# 2018-04-06 12:44:51.582009 - Thread-1 - train - 5.18s - 0
# 2018-04-06 12:44:51.716773 - Thread-2 - train - 5.14s - 50000
#
#
# 2018-04-06 12:45:57.819691 - Thread-1 - train - 66.24s - 100
#
# 2018-04-06 12:45:58.093194 - Thread-2 - train - 66.38s - 50100
#
# 2018-04-06 12:47:28.521286 - Thread-1 - train - 90.7s - 200
#
# 2018-04-06 12:47:30.608342 - Thread-2 - train - 92.52s - 50200
#
# 2018-04-06 12:48:48.618283 - Thread-1 - train - 80.1s - 300
#
# 2018-04-06 12:49:10.285978 - Thread-2 - train - 99.68s - 50300
#
# 2018-04-06 12:50:28.414232 - Thread-1 - train - 99.8s - 400
#
# 2018-04-06 12:50:48.077718 - Thread-2 - train - 97.79s - 50400
#
# 2018-04-06 12:52:06.182246 - Thread-1 - train - 97.77s - 500
#
# 2018-04-06 12:52:26.957058 - Thread-2 - train - 98.88s - 50500
#
# 2018-04-06 12:54:01.885775 - Thread-1 - train - 115.7s - 600
#
# 2018-04-06 12:54:21.224527 - Thread-2 - train - 114.27s - 50600
#
# ...
